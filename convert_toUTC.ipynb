# %%
import pandas as pd
import numpy as np

# %%
fpath = 'C:\\Users\\gg00642\\OneDrive - University of Surrey\\Desktop\\Actigraphy Sara'
#fpath = 'C:\\Users\\gianl\\Desktop\\Actigraphy Sara'

# %%
df = pd.read_excel(fpath + '\\1.0_sleep_calcs_all_joined.xlsx', sheet_name='sleep1')

# %%
df.head()
# Out:
#            start_time            end_time       date   duration  \
# 0 2022-09-21 22:08:00 2022-09-22 06:56:00 2022-09-22   8.800000
# 1 2022-09-22 20:28:00 2022-09-23 06:49:00 2022-09-23  10.341667
# 2 2022-09-23 21:06:00 2022-09-24 06:48:00 2022-09-24   9.708333
# 3 2022-09-24 22:15:00 2022-09-25 08:08:00 2022-09-25   9.883333
# 4 2022-09-25 22:43:00 2022-09-26 06:54:00 2022-09-26   8.183333
#
#              midpoint  location  weekday(1=free days) midpoint_time  \
# 0 2022-09-22 02:32:00         0                     0      02:32:30
# 1 2022-09-23 01:38:00         0                     0      01:38:45
# 2 2022-09-24 01:57:00         0                     1      01:57:15
# 3 2022-09-25 03:11:00         0                     1      03:11:30
# 4 2022-09-26 02:48:00         0                     0      02:48:30
#
#    midpoint_h sleep_start sleep_end  sleep_start_decimal  sleep_end_decimal
# 0   26.541667    22:08:30  06:56:30            22.141667          30.941667
# 1   25.645833    20:28:30  06:49:00            20.475000          30.816667
# 2   25.954167    21:06:00  06:48:30            21.100000          30.808333
# 3   27.191667    22:15:00  08:08:00            22.250000          32.133333
# 4   26.808333    22:43:00  06:54:00            22.716667          30.900000

# %%
# Define date ranges
date_ranges_location_0_subtract_2 = [
    ('2022-03-27 02:00', '2022-10-30 03:00'),
    ('2023-03-26 02:00', '2023-10-29 03:00'),
    ('2024-03-31 02:00', '2024-10-27 03:00')
]

date_ranges_location_1_subtract_1 = [
    ('2022-03-27 02:00', '2022-10-30 03:00'),
    ('2023-03-26 02:00', '2023-10-29 03:00'),
    ('2024-03-31 02:00', '2024-10-27 03:00')
]

date_ranges_location_0_subtract_1 = [
    ('2022-10-30 03:00', '2023-03-27 02:00'),
    ('2023-10-29 03:00', '2024-03-31 02:00'),
    ('2024-10-27 03:00', '2025-03-30 02:00')
]

# %%
def adjust_value(row):
    start_time = row['start_time']
    location = row['location']
    
    if location == 0:
        for start, end in date_ranges_location_0_subtract_2:
            if pd.to_datetime(start) <= start_time <= pd.to_datetime(end):
                return row['sleep_start_decimal'] - 2, row['sleep_end_decimal'] - 2, row['midpoint_h'] - 2
        for start, end in date_ranges_location_0_subtract_1:
            if pd.to_datetime(start) <= start_time <= pd.to_datetime(end):
                return row['sleep_start_decimal'] - 1, row['sleep_end_decimal'] - 1, row['midpoint_h'] - 1
    elif location == 1:
        for start, end in date_ranges_location_1_subtract_1:
            if pd.to_datetime(start) <= start_time <= pd.to_datetime(end):
                return row['sleep_start_decimal'] - 1, row['sleep_end_decimal'] - 1, row['midpoint_h'] - 1
    
    return row['sleep_start_decimal'], row['sleep_end_decimal'], row['midpoint_h']

df['start_time'] = pd.to_datetime(df['start_time'])  # Convert 'start_time' column to datetime

df[['sleep_start_decimal_UTC', 'sleep_end_decimal_UTC', 'midpoint_h_UTC']] = df.apply(adjust_value, axis=1, result_type='expand')

print(df)
# Out:
#              start_time            end_time       date   duration  \
# 0   2022-09-21 22:08:00 2022-09-22 06:56:00 2022-09-22   8.800000
# 1   2022-09-22 20:28:00 2022-09-23 06:49:00 2022-09-23  10.341667
# 2   2022-09-23 21:06:00 2022-09-24 06:48:00 2022-09-24   9.708333
# 3   2022-09-24 22:15:00 2022-09-25 08:08:00 2022-09-25   9.883333
# 4   2022-09-25 22:43:00 2022-09-26 06:54:00 2022-09-26   8.183333
# ..                  ...                 ...        ...        ...
# 643 2024-11-28 04:10:00 2024-11-28 11:13:00 2024-11-28   7.500000
# 644 2024-11-29 02:28:00 2024-11-29 13:18:00 2024-11-29  10.833333
# 645 2024-12-01 07:20:00 2024-12-01 10:50:00 2024-12-01   3.500000
# 646 2024-12-02 04:10:00 2024-12-02 12:22:00 2024-12-02   8.200000
# 647 2024-12-03 04:44:00 2024-12-03 09:15:00 2024-12-03   4.516667
#
#                midpoint  location  weekday(1=free days) midpoint_time  \
# 0   2022-09-22 02:32:00         0                     0      02:32:30
# 1   2022-09-23 01:38:00         0                     0      01:38:45
# 2   2022-09-24 01:57:00         0                     1      01:57:15
# 3   2022-09-25 03:11:00         0                     1      03:11:30
# 4   2022-09-26 02:48:00         0                     0      02:48:30
# ..                  ...       ...                   ...           ...
# 643 2024-11-28 07:41:00         0                     0      07:41:30
# 644 2024-11-29 07:53:00         0                     0      07:53:00
# 645 2024-12-01 09:05:00         0                     1      09:05:00
# 646 2024-12-02 08:16:00         0                     0      08:16:00
# 647 2024-12-03 06:59:00         1                     0      06:59:30
#
#      midpoint_h sleep_start sleep_end  sleep_start_decimal  sleep_end_decimal  \
# 0     26.541667    22:08:30  06:56:30            22.141667          30.941667
# 1     25.645833    20:28:30  06:49:00            20.475000          30.816667
# 2     25.954167    21:06:00  06:48:30            21.100000          30.808333
# 3     27.191667    22:15:00  08:08:00            22.250000          32.133333
# 4     26.808333    22:43:00  06:54:00            22.716667          30.900000
# ..          ...         ...       ...                  ...                ...
# 643   31.683333    04:10:00  11:13:00            28.166667          35.216667
# 644   31.883333    02:28:00  13:18:00            26.466667          37.300000
# 645   33.083333    07:20:00  10:50:00            31.333333          34.833333
# 646   32.266667    04:10:00  12:22:00            28.166667          36.366667
# 647   30.983333    04:44:00  09:15:00            28.733333          33.250000
#
#      sleep_start_decimal_UTC  sleep_end_decimal_UTC  midpoint_h_UTC
# 0                  20.141667              28.941667       24.541667
# 1                  18.475000              28.816667       23.645833
# 2                  19.100000              28.808333       23.954167
# 3                  20.250000              30.133333       25.191667
# 4                  20.716667              28.900000       24.808333
# ..                       ...                    ...             ...
# 643                27.166667              34.216667       30.683333
# 644                25.466667              36.300000       30.883333
# 645                30.333333              33.833333       32.083333
# 646                27.166667              35.366667       31.266667
# 647                28.733333              33.250000       30.983333
#
# [648 rows x 16 columns]

# %%
df.to_excel(fpath + '\\1a.0_sleep_calcs_all_joined_UTC.xlsx', index=False)
